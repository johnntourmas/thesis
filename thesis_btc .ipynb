# %% [markdown]
# ### Data
#
# Data Link: https://www.cryptodatadownload.com/data/
#
# ### About our data
#
# Dataset contains the bitcoin price info per minute.
#
# The info we interested in, is the close column.
#
# Close is the price of BTC at this moment.
# Volume is the ammount of BTC which bought or sold at this moment.
# Open price is the price which open the data in this one minute, the low
# price is the lowest price which reach at that moment and the high price is
# the highest price which reach at that moment.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score
from sklearn.preprocessing import MinMaxScaler
import random
import time
import copy
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
import tensorflow as tf
# %matplotlib inline

# %%
# size of dataframe
ROWS_OF_DATASET = 1440 * 10
#### LSTM ###
# size of test data 
TEST_DATA_LSTM = 1440 * 1
# size of input in lstm
LOOK_BACK_LSTM = 10
# size of lstm units
LSTM_UNITS = 32
# percentage of train data that will be our validation data
VALIDATION_DATA = 0.2
# how many days we want to forecast
FORECASTING_MINUTES = 360

### RRL ###
# we want train data end in the same spot with lstm data
TRAIN_DATA_RRL = ROWS_OF_DATASET - TEST_DATA_LSTM
LOOK_BACK_RRL = LOOK_BACK_LSTM
EPOCHS_RRL = 1000
LEARNING_RATE_RRL = 0.5

# %% [markdown]
# ## Import data

# %%
btc_input_df  = pd.read_csv("BTC-USD.csv", parse_dates=["time"], nrows=ROWS_OF_DATASET)
btc_input_df.head()
# Out:
#                  time       low      high      open     close    volume
# 0 2021-10-30 03:00:00  61868.81  61920.00  61888.18  61919.98  2.946079
# 1 2021-10-30 02:59:00  61882.74  61912.67  61903.16  61882.74  2.942357
# 2 2021-10-30 02:58:00  61854.82  61907.96  61854.82  61903.15  3.047848
# 3 2021-10-30 02:57:00  61848.04  61883.02  61883.01  61851.39  3.381070
# 4 2021-10-30 02:56:00  61879.33  61925.42  61907.47  61882.28  5.663128

# %%
btc_input_df = btc_input_df.set_index('time')
btc_input_df.head()
# Out:
#                           low      high      open     close    volume
# time
# 2021-10-30 03:00:00  61868.81  61920.00  61888.18  61919.98  2.946079
# 2021-10-30 02:59:00  61882.74  61912.67  61903.16  61882.74  2.942357
# 2021-10-30 02:58:00  61854.82  61907.96  61854.82  61903.15  3.047848
# 2021-10-30 02:57:00  61848.04  61883.02  61883.01  61851.39  3.381070
# 2021-10-30 02:56:00  61879.33  61925.42  61907.47  61882.28  5.663128

# %%
btc_input_df = btc_input_df.sort_index()
btc_input_df.head()
# Out:
#                           low      high      open     close    volume
# time
# 2021-10-20 03:01:00  63816.52  63860.23  63839.44  63823.36  2.736049
# 2021-10-20 03:02:00  63812.47  63835.33  63823.36  63827.88  3.145124
# 2021-10-20 03:03:00  63810.00  63837.24  63827.56  63810.01  6.178755
# 2021-10-20 03:04:00  63792.27  63823.50  63810.00  63817.06  4.367886
# 2021-10-20 03:05:00  63806.39  63849.85  63813.21  63847.04  6.441521

# %%
print(btc_input_df.shape)
print("------------------------")
print(btc_input_df.info())
# Out:
# (14400, 5)
# ------------------------
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14400 entries, 2021-10-20 03:01:00 to 2021-10-30 03:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   low     14400 non-null  float64
#  1   high    14400 non-null  float64
#  2   open    14400 non-null  float64
#  3   close   14400 non-null  float64
#  4   volume  14400 non-null  float64
# dtypes: float64(5)
# memory usage: 675.0 KB
# None

# %%
btc_input_df.head()
# Out:
#                           low      high      open     close    volume
# time
# 2021-10-20 03:01:00  63816.52  63860.23  63839.44  63823.36  2.736049
# 2021-10-20 03:02:00  63812.47  63835.33  63823.36  63827.88  3.145124
# 2021-10-20 03:03:00  63810.00  63837.24  63827.56  63810.01  6.178755
# 2021-10-20 03:04:00  63792.27  63823.50  63810.00  63817.06  4.367886
# 2021-10-20 03:05:00  63806.39  63849.85  63813.21  63847.04  6.441521

# %%
btc_input_df.tail()
# Out:
#                           low      high      open     close    volume
# time
# 2021-10-30 02:56:00  61879.33  61925.42  61907.47  61882.28  5.663128
# 2021-10-30 02:57:00  61848.04  61883.02  61883.01  61851.39  3.381070
# 2021-10-30 02:58:00  61854.82  61907.96  61854.82  61903.15  3.047848
# 2021-10-30 02:59:00  61882.74  61912.67  61903.16  61882.74  2.942357
# 2021-10-30 03:00:00  61868.81  61920.00  61888.18  61919.98  2.946079

# %% [markdown]
# ## Plot informations

# %%
plt.figure(figsize=(20,5))
plt.title("Bitcoin Price", fontsize=20)
btc_input_df.close.plot(figsize=(25,5))
plt.xlabel("Time", fontsize=15)
plt.ylabel("USD", fontsize=15)
plt.tight_layout()

# %%
plt.figure(figsize=(25,5))
plt.suptitle('Area Plots', fontsize=22)

plt.subplot(1,2,1)
btc_input_df.close.diff().plot.area(stacked=False,)
plt.ylabel("USD", fontsize="15")
plt.xlabel("Time", fontsize="15")
plt.title("Differences", fontsize="15")

plt.subplot(1,2,2)
btc_input_df.close.pct_change().plot.area(stacked=False,)
plt.ylabel("Percentage", fontsize="15")
plt.xlabel("Time", fontsize="15")
plt.title("Percentage Change", fontsize="15")

plt.tight_layout()

# %%
plt.figure(figsize=(25,12))

plt.subplot(3,3,1)
btc_input_df.close.hist(bins=150)
plt.xlabel("USD", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.title('Close', fontsize=15)

plt.subplot(3,3,2)
btc_input_df.close.pct_change().hist(bins=150)
plt.xlabel("Percentage", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.title('Percentage Change', fontsize=15)

plt.subplot(3,3,3)
btc_input_df.close.diff().hist(bins=150)
plt.xlabel("USD", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.title('Differences', fontsize=15)

plt.tight_layout()

# %%
# κάνουμε plot το corelation 
plt.figure(figsize=(20,12))

plt.subplot(3,3,1)
pd.plotting.lag_plot(btc_input_df['close'], lag=1) #minute lag
plt.xlabel("y(t)", fontsize=15)
plt.ylabel("y(t + 1)", fontsize=15)
plt.title('1-Minute Lag', fontsize=15)

plt.subplot(3,3,2)
pd.plotting.lag_plot(btc_input_df['close'], lag=5) 
plt.xlabel("y(t)", fontsize=15)
plt.ylabel("y(t + 5)", fontsize=15)
plt.title('5-Minute Lag', fontsize=15)

plt.subplot(3,3,3)
pd.plotting.lag_plot(btc_input_df['close'], lag=15) 
plt.xlabel("y(t)", fontsize=15)
plt.ylabel("y(t + 15)", fontsize=15)
plt.title('15-Minute Lag', fontsize=15)

plt.tight_layout()

# %% [markdown]
# ## Pre processing data for LSTM model

# %%
btc_closing_price = btc_input_df['close'].copy()
btc_closing_price.head()
# Out:
# time
# 2021-10-20 03:01:00    63823.36
# 2021-10-20 03:02:00    63827.88
# 2021-10-20 03:03:00    63810.01
# 2021-10-20 03:04:00    63817.06
# 2021-10-20 03:05:00    63847.04
# Name: close, dtype: float64

# %%
df_train= btc_closing_price[:-TEST_DATA_LSTM].copy()
df_test= btc_closing_price[-TEST_DATA_LSTM:].copy()

# %%
plt.figure(figsize=(20,5))
plt.plot(df_train, label='Train', linewidth=2, )
plt.plot(df_test, label='Test', linewidth=2)
plt.xlabel("Date", fontsize=15)
plt.ylabel('USD', fontsize=15)
plt.title('Train Data VS Test Data', fontsize=20)
plt.legend(loc='best', fontsize=15)
plt.tight_layout()

# %%
df_train= df_train.values.reshape(df_train.shape[0],1)
df_test= df_test.values.reshape(df_test.shape[0],1)

# %%
df_train.shape
# Out:
# (12960, 1)

# %%
scaler_train = MinMaxScaler(feature_range=(-1, 1))
scaled_train = scaler_train.fit_transform(df_train)

scaler_test = MinMaxScaler(feature_range=(-1, 1))
scaled_test = scaler_test.fit_transform(df_test)

# %%
def dataset_generator_lstm(dataset, look_back=10):
    dataX, dataY = [], []
    
    for i in range(len(dataset) - look_back):   
        window_size_x = dataset[i:(i + look_back)]
        dataX.append(window_size_x)
        dataY.append(dataset[i + look_back])
        
    return np.array(dataX), np.array(dataY)

trainX, trainY = dataset_generator_lstm(scaled_train, look_back= LOOK_BACK_LSTM)
testX, testY = dataset_generator_lstm(scaled_test, look_back= LOOK_BACK_LSTM)

print("trainX: ", trainX.shape)
print("trainY: ", trainY.shape)
print("testΧ: ", testX.shape)
print("testY", testY.shape)
# Out:
# trainX:  (12950, 10, 1)
# trainY:  (12950, 1)
# testΧ:  (1430, 10, 1)
# testY (1430, 1)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1 ))

print("Shape of trainX: ", trainX.shape)
print("Shape of testX: ", testX.shape)
# Out:
# Shape of trainX:  (12950, 10, 1)
# Shape of testX:  (1430, 10, 1)

# %% [markdown]
# ## Create LSTM model

# %%
model = Sequential()

model.add(LSTM(units=LSTM_UNITS, activation ='tanh', return_sequences=False, input_shape = (trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.2))

# model.add(LSTM(units = 64, activation = 'tanh', return_sequences=True, input_shape = (trainX.shape[1], trainX.shape[2])))
# model.add(Dropout(0.2))

# model.add(LSTM(units = 32, activation = 'tanh', return_sequences=False, input_shape = (trainX.shape[1], trainX.shape[2])))
# model.add(Dropout(0.2))

# model.add(LSTM(units = 64, activation = 'tanh', return_sequences=True, input_shape = (trainX.shape[1], trainX.shape[2])))
# model.add(Dropout(0.2))

# model.add(LSTM(units = 64, activation = 'tanh',return_sequences=False,input_shape = (trainX.shape[1], trainX.shape[2])))
# model.add(Dropout(0.2))

model.add(Dense(units = 1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                4352
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
checkpoint_path = f'./models/btc_model_{int(time.time())}.hdf5'
checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')

earlystopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
callbacks = [checkpoint, earlystopping]
history = model.fit(trainX, trainY, batch_size = 64, epochs = 100, 
                    verbose=1, shuffle=False, 
                    validation_split=VALIDATION_DATA, callbacks=callbacks)
# Out:
# Epoch 1/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0343
# Epoch 1: val_loss improved from inf to 0.01783, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 8s 21ms/step - loss: 0.0340 - val_loss: 0.0178
# Epoch 2/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 2: val_loss improved from 0.01783 to 0.00300, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 3/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0030
# Epoch 3: val_loss improved from 0.00300 to 0.00177, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 3s 19ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 4/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 4: val_loss improved from 0.00177 to 0.00151, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 5/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 5: val_loss did not improve from 0.00151
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 6/100
# 162/162 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 6: val_loss improved from 0.00151 to 0.00124, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 3s 20ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 7/100
# 162/162 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 7: val_loss improved from 0.00124 to 0.00120, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 3s 19ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 8/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 8: val_loss improved from 0.00120 to 0.00106, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 9/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 9: val_loss did not improve from 0.00106
# 162/162 [==============================] - 3s 20ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 10/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 10: val_loss improved from 0.00106 to 0.00104, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 3s 19ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 11/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 11: val_loss did not improve from 0.00104
# 162/162 [==============================] - 3s 19ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 12/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 12: val_loss improved from 0.00104 to 0.00096, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0018 - val_loss: 9.5721e-04
# Epoch 13/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 13: val_loss improved from 0.00096 to 0.00093, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0019 - val_loss: 9.2984e-04
# Epoch 14/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 14: val_loss did not improve from 0.00093
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0018 - val_loss: 9.7831e-04
# Epoch 15/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 15: val_loss improved from 0.00093 to 0.00086, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0018 - val_loss: 8.5523e-04
# Epoch 16/100
# 162/162 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 16: val_loss improved from 0.00086 to 0.00082, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0016 - val_loss: 8.1582e-04
# Epoch 17/100
# 162/162 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 17: val_loss did not improve from 0.00082
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0018 - val_loss: 9.7533e-04
# Epoch 18/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 18: val_loss did not improve from 0.00082
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0017 - val_loss: 9.1312e-04
# Epoch 19/100
# 156/162 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 19: val_loss did not improve from 0.00082
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 20/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 20: val_loss improved from 0.00082 to 0.00079, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0018 - val_loss: 7.8824e-04
# Epoch 21/100
# 162/162 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 21: val_loss improved from 0.00079 to 0.00069, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0018 - val_loss: 6.8880e-04
# Epoch 22/100
# 162/162 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 22: val_loss did not improve from 0.00069
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0019 - val_loss: 8.9589e-04
# Epoch 23/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 23: val_loss did not improve from 0.00069
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0019 - val_loss: 6.9165e-04
# Epoch 24/100
# 156/162 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 24: val_loss did not improve from 0.00069
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0017 - val_loss: 7.2408e-04
# Epoch 25/100
# 162/162 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 25: val_loss did not improve from 0.00069
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0017 - val_loss: 7.9263e-04
# Epoch 26/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 26: val_loss did not improve from 0.00069
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0017 - val_loss: 6.9960e-04
# Epoch 27/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 27: val_loss did not improve from 0.00069
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0017 - val_loss: 7.2551e-04
# Epoch 28/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 28: val_loss improved from 0.00069 to 0.00067, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0018 - val_loss: 6.7128e-04
# Epoch 29/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 29: val_loss improved from 0.00067 to 0.00065, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 6.4936e-04
# Epoch 30/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 30: val_loss improved from 0.00065 to 0.00063, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 6.3205e-04
# Epoch 31/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 31: val_loss improved from 0.00063 to 0.00062, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 6.1672e-04
# Epoch 32/100
# 155/162 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 32: val_loss did not improve from 0.00062
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 6.6979e-04
# Epoch 33/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 33: val_loss improved from 0.00062 to 0.00059, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 5.8868e-04
# Epoch 34/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 34: val_loss did not improve from 0.00059
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0017 - val_loss: 6.1454e-04
# Epoch 35/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 35: val_loss did not improve from 0.00059
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 6.6568e-04
# Epoch 36/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 36: val_loss did not improve from 0.00059
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 5.9174e-04
# Epoch 37/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 37: val_loss did not improve from 0.00059
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 6.0952e-04
# Epoch 38/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 38: val_loss did not improve from 0.00059
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 6.5443e-04
# Epoch 39/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 39: val_loss improved from 0.00059 to 0.00055, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 5.5057e-04
# Epoch 40/100
# 156/162 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 40: val_loss did not improve from 0.00055
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 6.5681e-04
# Epoch 41/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 41: val_loss did not improve from 0.00055
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 6.2936e-04
# Epoch 42/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 42: val_loss did not improve from 0.00055
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 6.0709e-04
# Epoch 43/100
# 155/162 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 43: val_loss improved from 0.00055 to 0.00054, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 5.3905e-04
# Epoch 44/100
# 156/162 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 44: val_loss did not improve from 0.00054
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 5.4840e-04
# Epoch 45/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 45: val_loss improved from 0.00054 to 0.00053, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 5.2554e-04
# Epoch 46/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 46: val_loss improved from 0.00053 to 0.00052, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 5.2132e-04
# Epoch 47/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 47: val_loss did not improve from 0.00052
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 5.2451e-04
# Epoch 48/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 48: val_loss did not improve from 0.00052
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 5.7761e-04
# Epoch 49/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 49: val_loss did not improve from 0.00052
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 6.4438e-04
# Epoch 50/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 50: val_loss improved from 0.00052 to 0.00051, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 5.0750e-04
# Epoch 51/100
# 155/162 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 51: val_loss improved from 0.00051 to 0.00050, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 5.0114e-04
# Epoch 52/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 52: val_loss did not improve from 0.00050
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 6.0753e-04
# Epoch 53/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 53: val_loss did not improve from 0.00050
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 5.4002e-04
# Epoch 54/100
# 156/162 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 54: val_loss did not improve from 0.00050
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 5.3113e-04
# Epoch 55/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 55: val_loss improved from 0.00050 to 0.00050, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 4.9571e-04
# Epoch 56/100
# 155/162 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 56: val_loss did not improve from 0.00050
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 4.9808e-04
# Epoch 57/100
# 162/162 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 57: val_loss did not improve from 0.00050
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 5.8213e-04
# Epoch 58/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 58: val_loss improved from 0.00050 to 0.00049, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 4.8619e-04
# Epoch 59/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 59: val_loss improved from 0.00049 to 0.00048, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 4.7621e-04
# Epoch 60/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 60: val_loss did not improve from 0.00048
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 6.0188e-04
# Epoch 61/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 61: val_loss did not improve from 0.00048
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 5.2685e-04
# Epoch 62/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 62: val_loss did not improve from 0.00048
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 5.1249e-04
# Epoch 63/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 63: val_loss improved from 0.00048 to 0.00046, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 4.5876e-04
# Epoch 64/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 64: val_loss did not improve from 0.00046
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 4.5884e-04
# Epoch 65/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 65: val_loss did not improve from 0.00046
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 4.8047e-04
# Epoch 66/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 66: val_loss did not improve from 0.00046
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 4.8760e-04
# Epoch 67/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 67: val_loss improved from 0.00046 to 0.00045, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 4.4878e-04
# Epoch 68/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 68: val_loss did not improve from 0.00045
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 4.8092e-04
# Epoch 69/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 69: val_loss did not improve from 0.00045
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 4.5942e-04
# Epoch 70/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 70: val_loss did not improve from 0.00045
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 4.7456e-04
# Epoch 71/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 71: val_loss did not improve from 0.00045
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 4.5390e-04
# Epoch 72/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 72: val_loss did not improve from 0.00045
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 4.8289e-04
# Epoch 73/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 73: val_loss did not improve from 0.00045
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 4.5555e-04
# Epoch 74/100
# 156/162 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 74: val_loss improved from 0.00045 to 0.00044, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 4.3715e-04
# Epoch 75/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 75: val_loss did not improve from 0.00044
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.5954e-04
# Epoch 76/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 76: val_loss did not improve from 0.00044
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 4.4720e-04
# Epoch 77/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 77: val_loss did not improve from 0.00044
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 4.3828e-04
# Epoch 78/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 78: val_loss did not improve from 0.00044
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0014 - val_loss: 4.5134e-04
# Epoch 79/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 79: val_loss improved from 0.00044 to 0.00043, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0013 - val_loss: 4.3011e-04
# Epoch 80/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 80: val_loss did not improve from 0.00043
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 4.7912e-04
# Epoch 81/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 81: val_loss did not improve from 0.00043
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.3643e-04
# Epoch 82/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 82: val_loss did not improve from 0.00043
# 162/162 [==============================] - 2s 12ms/step - loss: 0.0014 - val_loss: 4.6109e-04
# Epoch 83/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 83: val_loss improved from 0.00043 to 0.00043, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 2s 10ms/step - loss: 0.0014 - val_loss: 4.2838e-04
# Epoch 84/100
# 162/162 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 84: val_loss did not improve from 0.00043
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.3270e-04
# Epoch 85/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 85: val_loss did not improve from 0.00043
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.3915e-04
# Epoch 86/100
# 157/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 86: val_loss improved from 0.00043 to 0.00042, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.2317e-04
# Epoch 87/100
# 156/162 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 87: val_loss did not improve from 0.00042
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 4.2406e-04
# Epoch 88/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 88: val_loss did not improve from 0.00042
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.6649e-04
# Epoch 89/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 89: val_loss improved from 0.00042 to 0.00042, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.1985e-04
# Epoch 90/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 90: val_loss did not improve from 0.00042
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 4.2922e-04
# Epoch 91/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 91: val_loss did not improve from 0.00042
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0013 - val_loss: 4.4636e-04
# Epoch 92/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 92: val_loss did not improve from 0.00042
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0013 - val_loss: 4.7297e-04
# Epoch 93/100
# 155/162 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 93: val_loss improved from 0.00042 to 0.00041, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0014 - val_loss: 4.1245e-04
# Epoch 94/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 94: val_loss did not improve from 0.00041
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.1300e-04
# Epoch 95/100
# 159/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 95: val_loss did not improve from 0.00041
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.1455e-04
# Epoch 96/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 96: val_loss did not improve from 0.00041
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.4679e-04
# Epoch 97/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 97: val_loss did not improve from 0.00041
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.1704e-04
# Epoch 98/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 98: val_loss did not improve from 0.00041
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.1654e-04
# Epoch 99/100
# 160/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 99: val_loss improved from 0.00041 to 0.00041, saving model to ./models/btc_model_1649605088.hdf5
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.1071e-04
# Epoch 100/100
# 158/162 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 100: val_loss did not improve from 0.00041
# 162/162 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 4.3026e-04

# %%
model_from_saved_checkpoint = load_model(checkpoint_path)

# %% [markdown]
# ## How good is our model?

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc='best', fontsize=15)
plt.xlabel("Epoch",fontsize=15)
plt.ylabel("Loss", fontsize=15)
plt.title("Model Performance", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Model Performance')

# %%
# Τα μετατρέπουμε στην κανονική τους μορφή και κάνουμε τις προβλέψεις
predicted_btc_price_test_data = model_from_saved_checkpoint.predict(testX)
predicted_btc_price_test_data = scaler_test.inverse_transform(predicted_btc_price_test_data.reshape(testX.shape[0], 1))
test_actual = scaler_test.inverse_transform(testY.reshape(testX.shape[0], 1))

def rmse(predictions, targets):
    return np.sqrt(np.mean((predictions-targets)**2))

print(f"Mean Absolute Error: {mean_absolute_error(predicted_btc_price_test_data, test_actual)}")
print(f"Mean Square Error: {mean_squared_error(predicted_btc_price_test_data, test_actual)}")
print(f"r2 score: {r2_score(predicted_btc_price_test_data, test_actual)}")
print(f"Root Mean Square Error: {rmse(predicted_btc_price_test_data, test_actual)}")
# Out:
# Mean Absolute Error: 42.08407954545458
# Mean Square Error: 3163.8405297718823
# r2 score: 0.9922408789147674
# Root Mean Square Error: 56.24802689669996

# %%
# Τα μετατρέπουμε στην κανονική τους μορφή και κάνουμε τις προβλέψεις
predicted_btc_price_train_data = model_from_saved_checkpoint.predict(trainX)
predicted_btc_price_train_data = scaler_train.inverse_transform(predicted_btc_price_train_data.reshape(trainX.shape[0], 1))
train_actual = scaler_train.inverse_transform(trainY.reshape(trainY.shape[0], 1))

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.plot(predicted_btc_price_train_data, 'r', marker='.', label='Predicted Train')
plt.plot(train_actual, marker='.', label='Actual Train', alpha=0.3)
plt.xlabel("Tick", fontsize=15)
plt.ylabel("USD", fontsize=15)
plt.title("Price", fontsize=20)
plt.legend(loc='best', fontsize='15')

plt.subplot(2,2,2)
plt.plot(np.diff(train_actual, axis=0),label='Actual Train', alpha=0.5, linewidth=2)
plt.plot(np.diff(predicted_btc_price_train_data, axis=0), label='Predicted Train', linewidth=2)
plt.xlabel("Tick", fontsize=15)
plt.ylabel("USD", fontsize=15)
plt.title("Price Differences", fontsize=20)
plt.legend(loc='best', fontsize='15')
plt.tight_layout()

plt.subplot(2,2,3)
plt.plot(predicted_btc_price_test_data, 'r', marker='.', label='Predicted Test')
plt.plot(test_actual, marker='.', label='Actual Test', alpha=0.3)
plt.xlabel("Tick", fontsize=15)
plt.ylabel("USD", fontsize=15)
plt.title("Price", fontsize=20)
plt.legend(loc='best', fontsize='15')

plt.subplot(2,2,4)
plt.plot(np.diff(test_actual, axis=0),label='Actual Test', alpha=0.5, linewidth=2)
plt.plot(np.diff(predicted_btc_price_test_data, axis=0), label='Predicted Test', linewidth=2)
plt.xlabel("Tick", fontsize=15)
plt.ylabel("USD", fontsize=15)
plt.title("Price Differences", fontsize=20)
plt.legend(loc='best', fontsize='15')
plt.tight_layout()

# %% [markdown]
# ## Forecasting

# %%
lookback_period = FORECASTING_MINUTES
testX_last_days = testX[testX.shape[0] - lookback_period:]
print(testX_last_days.shape)
predicted_days_forecast_price_test_x = []

for i in range(lookback_period):  
    predicted_forecast_price_test_x = model_from_saved_checkpoint.predict(testX_last_days[i:i+1])
    predicted_forecast_price_test_x = scaler_test.inverse_transform(predicted_forecast_price_test_x.reshape(-1, 1))
    predicted_days_forecast_price_test_x.append(predicted_forecast_price_test_x)

predicted_days_forecast_price_test_x = np.array(predicted_days_forecast_price_test_x)
predicted_days_forecast_price_test_x = predicted_days_forecast_price_test_x.flatten()

predicted_btc_price_test_data = predicted_btc_price_test_data.flatten()
predicted_btc_test_concatenated = np.concatenate((predicted_btc_price_test_data, predicted_days_forecast_price_test_x))
# Out:
# (360, 10, 1)

# %%
plt.figure(figsize=(20,10))

plt.subplot(2,2,1)
plt.plot(predicted_btc_test_concatenated, 'r', marker='.', label='Predicted Test')
plt.plot(test_actual, marker='.', label='Actual Test', alpha=0.3)
plt.xlabel("Tick", fontsize=15)
plt.ylabel("USD", fontsize=15)
plt.title("Price", fontsize=20)
plt.legend(loc='best', fontsize='15')

plt.subplot(2,2,2)
plt.plot(np.diff(test_actual, axis=0),label='Actual Test', alpha=0.5, linewidth=2)
plt.plot(np.diff(predicted_btc_test_concatenated, axis=0), label='Predicted Test', linewidth=2)
plt.xlabel("Tick", fontsize=15)
plt.ylabel("USD", fontsize=15)
plt.title("Price Differences", fontsize=20)
plt.legend(loc='best', fontsize='15')
plt.tight_layout()

# %% [markdown]
# ## Create dataframe for our trade positions

# %%
df_strategy_actual = pd.DataFrame(test_actual)
df_strategy_predicted = pd.DataFrame(predicted_btc_price_test_data)

df_strategy_actual = df_strategy_actual.rename(columns={0: "close"})
df_strategy_predicted = df_strategy_predicted.rename(columns={0: "close"})

# %%
def classify(current, future):
    if future is None:
        return
    """
    Επιστρέφει 1 αν η τιμή στο μέλλον είναι αυξημένη ή
    -1 αν η τιμή στο μέλλον είναι μειωμένη
    """
    if float(future) > float(current):
        return 1
    elif float(future) < float(current):
        return -1

# %%
df_strategy_actual['future'] = df_strategy_actual["close"].shift(-1)
df_strategy_predicted['future'] = df_strategy_predicted["close"].shift(-1)
df_strategy_actual['target'] = list(map(classify, df_strategy_actual["close"], df_strategy_actual["future"]))
df_strategy_predicted['target'] = list(map(classify, df_strategy_predicted["close"], df_strategy_predicted["future"]))

frames = [df_strategy_actual, df_strategy_predicted]
result = pd.concat(frames, axis=1, ignore_index=True)
result = result.rename(columns={0: "actual_close", 
                                1:"actual_future_close", 
                                2:"actual_target",
                                3:"predicted_close",
                                4:"predicted_future_close",
                                5:"predicted_target"})
result.dropna(inplace = True)
result["prcnt_change"] = (result['predicted_future_close'] - result['predicted_close'] ) / result['predicted_close']
result.reset_index(inplace=True, drop=True)
result.head(10)
# Out:
#    actual_close  actual_future_close  actual_target  predicted_close  \
# 0      61646.29             61614.14           -1.0     61618.792969
# 1      61614.14             61591.31           -1.0     61629.550781
# 2      61591.31             61614.43            1.0     61611.808594
# 3      61614.43             61582.86           -1.0     61588.968750
# 4      61582.86             61562.09           -1.0     61600.500000
# 5      61562.09             61589.65            1.0     61582.363281
# 6      61589.65             61624.06            1.0     61560.464844
# 7      61624.06             61608.43           -1.0     61575.574219
# 8      61608.43             61620.40            1.0     61609.277344
# 9      61620.40             61612.92           -1.0     61608.253906
#
#    predicted_future_close  predicted_target  prcnt_change
# 0            61629.550781               1.0      0.000175
# 1            61611.808594              -1.0     -0.000288
# 2            61588.968750              -1.0     -0.000371
# 3            61600.500000               1.0      0.000187
# 4            61582.363281              -1.0     -0.000294
# 5            61560.464844              -1.0     -0.000356
# 6            61575.574219               1.0      0.000245
# 7            61609.277344               1.0      0.000547
# 8            61608.253906              -1.0     -0.000017
# 9            61614.664062               1.0      0.000104

# %% [markdown]
# ## RRL Stock Trading

# %%
def positions(x, w):
    M = len(w) - 2
    T = len(x)
    Ft = np.zeros(T)
    for t in range(M, T):
        xt = np.concatenate([[1], x[t - M:t], [Ft[t - 1]]])
        Ft[t] = np.tanh(np.dot(w, xt))
    return Ft

def returns(Ft, x, delta=0):
    T = len(x)
    rets = Ft[0:T - 1] * x[1:T] - delta * np.abs(Ft[1:T] - Ft[0:T - 1])
    return np.concatenate([[0], rets])

def gradient(x, w, delta):
    Ft = positions(x, w)
    R = returns(Ft, x, delta)
    T = len(x)
    M = len(w) - 2
    
    A = np.mean(R)
    B = np.mean(np.square(R))
    S = A / np.sqrt(B - A ** 2)

    dSdA = S * (1 + S ** 2) / A
    dSdB = -S ** 3 / 2 / A ** 2
    dAdR = 1. / T
    dBdR = 2. / T * R
    
    grad = np.zeros(M + 2)  
    dFpdw = np.zeros(M + 2)  
    
    for t in range(M, T):
        xt = np.concatenate([[1], x[t - M:t], [Ft[t-1]]])
        dRdF = -delta * np.sign(Ft[t] - Ft[t-1])
        dRdFp = x[t] + delta * np.sign(Ft[t] - Ft[t-1])
        dFdw = (1 - Ft[t] ** 2) * (xt + w[-1] * dFpdw)
        dSdw = (dSdA * dAdR + dSdB * dBdR[t]) * (dRdF * dFdw + dRdFp * dFpdw)
        grad = grad + dSdw
        dFpdw = dFdw
        
    return grad, S

def train(x, epochs=2000, M=8, commission=0, learning_rate = 0.3):
    w = np.random.rand(M + 2)
    sharpes = np.zeros(epochs) 
    for i in range(epochs):
        grad, sharpe = gradient(x, w, commission)
        w = w + grad * learning_rate
        sharpes[i] = sharpe
    
    print("finished training")
    return w, sharpes

# %%
rets = btc_input_df['close'].copy().diff()[1:ROWS_OF_DATASET]
x = np.array(rets)
N = TRAIN_DATA_RRL 
x_train = x[:N]
x_test = x[N:]

# %%
x_test
# Out:
# array([-58.84,  -9.92,   7.99, ...,  51.76, -20.41,  37.24])

# %%
plt.figure(figsize=(15,5))
plt.plot(rets[:N], label='Train', linewidth=2,)
plt.plot(rets[N:], label='Test', linewidth=2,)
plt.ylabel('USD', fontsize=15)
plt.xlabel('Date', fontsize=15)
plt.title('Train Data VS Test Data', fontsize=16)
plt.legend(loc='best', fontsize=16)
plt.tight_layout()

# %%
# # standardizing the values
std = np.std(x_train)
mean = np.mean(x_train)
x_tr = x_train[:]

x_train = (x_train - mean) / std
# x_test = (x_test - mean) / std

# # for lstm predictions
x_lstm_test = np.diff(predicted_btc_price_test_data)
# x_lstm_test = (x_lstm_test - mean) / std

# %%
# %%time
np.random.seed(0)
print('start training')
w, sharpes = train(x_train, epochs=EPOCHS_RRL, M=LOOK_BACK_RRL, commission=0, learning_rate=LEARNING_RATE_RRL)
# Out:
# start training
# finished training
# CPU times: user 6min 23s, sys: 14.7 s, total: 6min 38s
# Wall time: 6min 25s

# %%
plt.figure(figsize=(10,5))
plt.title("Model Performance", fontsize=20)
plt.plot(sharpes)
plt.xlabel('Epoch Number', fontsize=15)
plt.ylabel('Sharpe Ratio', fontsize=15)
plt.tight_layout()
print(f"Sharpe ratio: {sharpes[-1]}")
# Out:
# Sharpe ratio: 0.04920700198651914

# %%
x_train = x_tr[:]
train_returns = returns(positions(x_train, w), x_train)
test_returns = returns(positions(x_test, w), x_test)

train_positions = positions(x_train, w)
test_positions = positions(x_test, w)

lstm_returns= returns(positions(x_lstm_test, w), x_test[:len(x_lstm_test)-1])
lstm_positions = positions(x_lstm_test, w)

# %%
plt.figure(figsize=(20,10))

plt.subplot(4,2,1)
plt.xlabel("Tick")
plt.ylabel("Ft")
plt.plot(train_positions)
plt.title("Train Ft (decisions)")

plt.subplot(4,2,2)
plt.xlabel("Tick")
plt.ylabel('USD')
plt.plot(train_returns)
plt.title("Train Returns")

plt.subplot(4,2,3)
plt.xlabel("Tick")
plt.ylabel("Ft")
plt.plot(test_positions)
plt.title("Test Ft (decisions)")

plt.subplot(4,2,4)
plt.xlabel("Tick")
plt.ylabel('USD')
plt.plot(test_returns)
plt.title("Test Returns")

plt.subplot(4,2,5)
plt.xlabel("Tick")
plt.ylabel('Ft')
plt.plot(lstm_positions)
plt.title("LSTM predictions Ft (decisions)")

plt.subplot(4,2,6)
plt.xlabel("Tick")
plt.ylabel('USD')
plt.plot(lstm_returns)
plt.title("LSTM predictions Returns")

plt.subplot(4,2,7)
plt.xlabel("Tick")
plt.ylabel('USD')
plt.plot(train_returns.cumsum(), label="RRL")

plt.subplot(4,2,7)
plt.xlabel("Tick")
plt.ylabel('USD')
plt.plot(x_train.cumsum(), color="green", label="Buy and Hold")
plt.title("Train Cumulative Returns VS Buy and Hold")
plt.legend()

plt.subplot(4,2,8)
plt.xlabel("Tick")
plt.ylabel('USD')
plt.plot(test_returns.cumsum(), label= "RRL")

plt.subplot(4,2,8)
plt.xlabel("Tick")
plt.plot(lstm_returns.cumsum(), label= "RRL ON LSTM")

plt.subplot(4,2,8)
plt.xlabel("Tick")
plt.plot(x_test.cumsum(), label= "Buy and Hold")
plt.title("Test Cumulative Returns VS LSTM Cumulative Returns VS Buy and Hold")
plt.legend(loc='best')

plt.tight_layout()

print(f"RL model on train data: {train_returns.cumsum()[-1]} USD" )
print(f"Buy and Hold - train Data: {x_train.cumsum()[-1]} USD")
print(f"RL model on test data: {test_returns.cumsum()[-1]} USD")
print(f"RL model on lstm predictions: {lstm_returns.cumsum()[-1]} USD")
print(f"Buy and Hold - test data: {x_test.cumsum()[-1]} USD")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:56: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:60: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# RL model on train data: 37356.43839822484 USD
# Buy and Hold - train Data: -2158.1200000000026 USD
# RL model on test data: 4184.8535354205405 USD
# RL model on lstm predictions: 19892.275290339854 USD
# Buy and Hold - test data: 254.74000000000524 USD

# %%
plt.figure(figsize=(15,12))
HIST_BINS = 50

plt.subplot(3,2,1)
plt.ylabel("Frequency", )
plt.xlabel("Ft")
plt.hist(train_positions, bins=HIST_BINS)
plt.title("Train Ft (decisions)")

plt.subplot(3,2,2)
plt.ylabel("Frequency", )
plt.xlabel("USD")
plt.hist(train_returns, bins=HIST_BINS, label="RRL")
plt.hist(x_train.cumsum(), bins=HIST_BINS, alpha=0.3, label="Buy and Hold")
plt.title("Train Returns")
plt.legend()

plt.subplot(3,2,3)
plt.xlabel("Ft")
plt.ylabel("Frequency", )
plt.hist(test_positions, bins=HIST_BINS)
plt.title("Test Ft (decisions)")

plt.subplot(3,2,4)
plt.xlabel("USD")
plt.ylabel("Frequency",)
plt.hist(test_returns, bins=HIST_BINS, label="RRL")
plt.hist(x_test.cumsum(), bins=HIST_BINS, alpha=0.3, label="Buy and Hold")
plt.title("Test Returns")
plt.legend()

plt.subplot(3,2,5)
plt.xlabel("Ft")
plt.ylabel("Frequency",)
plt.hist(lstm_positions, bins=HIST_BINS)
plt.title("LSTM Ft (decisions)")

plt.subplot(3,2,6)
plt.ylabel("Frequency", )
plt.xlabel("USD")
plt.hist(lstm_returns, bins=HIST_BINS, label="RRL on LSTM predictions")
plt.hist(x_test.cumsum(), bins=HIST_BINS, alpha=0.3, label="Buy and Hold")
plt.title("LSTM Returns")
plt.legend()

plt.tight_layout()

# %% [markdown]
# ## Functions for Trading

# %%
def trade_long(positions, stock_prices, usd=5000, btc=0, fee=0):
    """
    Αγοράζουμε για όσο προβλέπουμε πως θα ανέβει η τιμή και τα πουλάμε όλα 
    όταν προβλέπουμε πως θα πέσει η τιμή
    """
    cnt = 0
    total = []
    total.append(usd + btc * stock_prices[0])
    print(f"Start with: {total[0]} USD")
    for index in range(len(stock_prices) - 1): 

        # αγοράζουμε
        if positions[index] > 0 and usd > 0:
            buy = positions[index] * usd
            btc = buy / stock_prices[index] + btc
            usd = usd - buy - (fee * buy)
            cnt += 1
            total.append(usd + btc * stock_prices.iloc[index])
            continue

        # πουλάμε 
        if positions[index] < 0 and btc > 0: 
            usd = btc * stock_prices[index] + usd - (fee * btc)
            btc = 0
            cnt += 1
            total.append(usd + btc * stock_prices.iloc[index])
            continue
    
    print(f"End with: {total[-1]} USD\nProfit: {total[-1] - total[0]} USD\n# of trades: {cnt}\n")
    return total

def trade_short(positions, stock_prices, usd=0, btc=2, fee=0):
    """
    Στην συγκεκριμένη στρατηγική πουλάμε όλα τα bitcoin που έχουμε,
    και αγοράζουμε την ίδια ποσότητα που πουλήσαμε όταν προβλέπουμε πως θα ξαναανέβει η τιμή
    """
    cnt = 0
    total = []
    total.append(usd + btc * stock_prices[0])
    short = False
    first_btc = copy.deepcopy(btc)
    print(f"Start with: {total[0]} USD")
    for index in range(len(stock_prices) - 1): 
        # αγοράζουμε
        if positions[index] > 0  and usd > 0 and usd >= (first_btc) * stock_prices[index]:
            buy = copy.deepcopy(first_btc)
            btc = buy / stock_prices[index] + btc
            usd = usd - buy - (fee * buy)
            cnt += 1
            total.append(usd + btc * stock_prices.iloc[index])
            short = False
            continue

        # πουλάμε 
        if positions[index] < 0 and btc > first_btc - (first_btc / 2):  
            first_btc = copy.deepcopy(btc)
            usd = btc * stock_prices[index] + usd - (fee * btc)
            btc = 0
            cnt += 1
            total.append(usd + btc * stock_prices.iloc[index])
            short = True
            continue
        
    print(f"End with: {total[-1]} USD\nProfit: {total[-1] - total[0]} USD\n# of trades: {cnt}\n")
    
    return total

# %%
result['prcnt_change'].agg(['min', 'max', 'mean'])
# Out:
# min    -0.002469
# max     0.005254
# mean    0.000003
# Name: prcnt_change, dtype: float64

# %%
print("---RRL LONG---")
total_rrl_long = trade_long(positions(x_test[:], w), result['actual_close'].copy())
print("---RRL ON LSTM LONG---")
total_rrl_lstm_long = trade_long(positions(x_lstm_test, w), result['actual_close'].copy())
print("---LSTM LONG---")
total_lstm_long = trade_long(result['prcnt_change'] * 100, result['actual_close'].copy())
print("---------------------------------------------------")
print("---RRL SHORT---")
total_rrl_short = trade_short(positions(x_test[:], w), result['actual_close'].copy())
print("---RRL ON LSTM SHORT---")
total_rrl_lstm_short = trade_short(positions(x_lstm_test, w), result['actual_close'].copy())
print("---LSTM SHORT---")
total_lstm_short = trade_short(result['prcnt_change'], result['actual_close'].copy())

plt.figure(figsize=(24,10))
plt.subplot(2,2,1)
plt.plot(total_rrl_long, label="RRL", linewidth=2)
plt.plot(total_rrl_lstm_long, label="RRL on LSTM predictions", linewidth=2)
plt.plot(total_lstm_long, label="LSTM", linewidth=2)
plt.xlabel('Trade')
plt.ylabel('USD')
plt.legend(loc='best')
plt.title("PORTFOLIO - LONG", fontsize=20)

plt.subplot(2,2,2)
plt.plot(total_rrl_short, label="RRL", linewidth=2)
plt.plot(total_rrl_lstm_short, label="RRL on LSTM predictions", linewidth=2)
plt.plot(total_lstm_short, label="LSTM", linewidth=2)
plt.xlabel('Trade')
plt.ylabel('USD')
plt.legend()
plt.title("PORTFOLIO - SHORT", fontsize=20)
# Out:
# ---RRL LONG---
# Start with: 5000.0 USD
# End with: 5137.768016974763 USD
# Profit: 137.76801697476276 USD
# # of trades: 482
#
# ---RRL ON LSTM LONG---
# Start with: 5000.0 USD
# End with: 5171.888450092501 USD
# Profit: 171.88845009250144 USD
# # of trades: 423
#
# ---LSTM LONG---
# Start with: 5000.0 USD
# End with: 4997.804897147604 USD
# Profit: -2.195102852396303 USD
# # of trades: 978
#
# ---------------------------------------------------
# ---RRL SHORT---
# Start with: 123292.58 USD
# End with: 123543.42966657958 USD
# Profit: 250.84966657958284 USD
# # of trades: 333
#
# ---RRL ON LSTM SHORT---
# Start with: 123292.58 USD
# End with: 123228.2663884985 USD
# Profit: -64.3136115015077 USD
# # of trades: 315
#
# ---LSTM SHORT---
# Start with: 123292.58 USD
# End with: 123230.50545856734 USD
# Profit: -62.07454143266659 USD
# # of trades: 319
# Text(0.5, 1.0, 'PORTFOLIO - SHORT')
